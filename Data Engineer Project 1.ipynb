# %%
import psycopg2
import pandas as pd

# %%
def create_database():
    # connect to default database
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres \
                            user=postgres password=manager")
    conn.set_session(autocommit=True)
    cur = conn.cursor()
    
    # create sparkify database with UTF8 encoding
    cur.execute("DROP DATABASE IF EXISTS insurance")
    cur.execute("CREATE DATABASE insurance")
    
    # close connection to default database
    conn.close()
    
    # connect to sparkify database
    conn = psycopg2.connect("host=127.0.0.1 dbname=insurance \
                            user=postgres password=manager")
    cur = conn.cursor()
    
    return cur, conn

# %%
def drop_tables(cur, conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()

# %%
def create_tables(cur, conn):
    for query in create_table_queries:
        cur.execute(query)
        conn.commit()

# %%
ClaimData = pd.read_csv("data/Train_Claim.csv")

# %%
ClaimData.head()
# Out:
#   CustomerID DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0  Cust10000     2015-02-03   Multi-vehicle Collision   Side Collision
# 1  Cust10001     2015-02-02   Multi-vehicle Collision   Side Collision
# 2  Cust10002     2015-01-15  Single Vehicle Collision   Side Collision
# 3  Cust10003     2015-01-19  Single Vehicle Collision   Side Collision
# 4  Cust10004     2015-01-09  Single Vehicle Collision   Rear Collision
#
#   SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0         Total Loss               Police        State7        City1
# 1         Total Loss               Police        State7        City5
# 2       Minor Damage                Other        State8        City6
# 3       Minor Damage                Other        State9        City6
# 4       Minor Damage                 Fire        State8        City6
#
#   IncidentAddress  IncidentTime  NumberOfVehicles PropertyDamage  \
# 0   Location 1311            17                 3              ?
# 1   Location 1311            10                 3            YES
# 2   Location 2081            22                 1            YES
# 3   Location 2081            22                 1            YES
# 4   Location 1695            10                 1             NO
#
#    BodilyInjuries Witnesses PoliceReport AmountOfTotalClaim  \
# 0               1         0            ?              65501
# 1               2         1          YES              61382
# 2               2         3           NO              66755
# 3               2         3           NO              66243
# 4               2         1          YES              53544
#
#    AmountOfInjuryClaim  AmountOfPropertyClaim  AmountOfVehicleDamage
# 0                13417                   6071                  46013
# 1                15560                   5919                  39903
# 2                11630                  11630                  43495
# 3                12003                  12003                  42237
# 4                 8829                   7234                  37481

# %%
ClaimData_clean = ClaimData[['CustomerID','TypeOfIncident','TypeOfCollission',
                             'IncidentState','AmountOfTotalClaim']]

# %%
ClaimData_clean.head()
# Out:
#   CustomerID            TypeOfIncident TypeOfCollission IncidentState  \
# 0  Cust10000   Multi-vehicle Collision   Side Collision        State7
# 1  Cust10001   Multi-vehicle Collision   Side Collision        State7
# 2  Cust10002  Single Vehicle Collision   Side Collision        State8
# 3  Cust10003  Single Vehicle Collision   Side Collision        State9
# 4  Cust10004  Single Vehicle Collision   Rear Collision        State8
#
#   AmountOfTotalClaim
# 0              65501
# 1              61382
# 2              66755
# 3              66243
# 4              53544

# %%
DemographicsData = pd.read_csv("data/Train_Demographics.csv")

# %%
DemographicsData.head()
# Out:
#   CustomerID  InsuredAge  InsuredZipCode InsuredGender InsuredEducationLevel  \
# 0  Cust10000          35          454776          MALE                    JD
# 1  Cust10001          36          454776          MALE                    JD
# 2  Cust10002          33          603260          MALE                    JD
# 3  Cust10003          36          474848          MALE                    JD
# 4  Cust10004          29          457942        FEMALE           High School
#
#   InsuredOccupation InsuredHobbies  CapitalGains  CapitalLoss Country
# 0      armed-forces         movies         56700       -48500   India
# 1      tech-support      cross-fit         70600       -48500   India
# 2      armed-forces           polo         66400       -63700   India
# 3      armed-forces           polo         47900       -73400   India
# 4   exec-managerial        dancing             0       -41500   India

# %%
DemographicsData.columns
# Out:
# Index(['CustomerID', 'InsuredAge', 'InsuredZipCode', 'InsuredGender',
#        'InsuredEducationLevel', 'InsuredOccupation', 'InsuredHobbies',
#        'CapitalGains', 'CapitalLoss', 'Country'],
#       dtype='object')

# %%
DemographicsData = DemographicsData.drop(['InsuredZipCode','CapitalGains','CapitalLoss','Country'],axis=1)

# %%
DemographicsData.head()
# Out:
#   CustomerID  InsuredAge InsuredGender InsuredEducationLevel  \
# 0  Cust10000          35          MALE                    JD
# 1  Cust10001          36          MALE                    JD
# 2  Cust10002          33          MALE                    JD
# 3  Cust10003          36          MALE                    JD
# 4  Cust10004          29        FEMALE           High School
#
#   InsuredOccupation InsuredHobbies
# 0      armed-forces         movies
# 1      tech-support      cross-fit
# 2      armed-forces           polo
# 3      armed-forces           polo
# 4   exec-managerial        dancing

# %%
PolicyData = pd.read_csv("data/Train_Policy.csv")

# %%
PolicyData.columns
# Out:
# Index(['InsurancePolicyNumber', 'CustomerLoyaltyPeriod',
#        'DateOfPolicyCoverage', 'InsurancePolicyState',
#        'Policy_CombinedSingleLimit', 'Policy_Deductible',
#        'PolicyAnnualPremium', 'UmbrellaLimit', 'InsuredRelationship',
#        'CustomerID'],
#       dtype='object')

# %%
PolicyData = PolicyData[['CustomerLoyaltyPeriod','InsurancePolicyState',
                         'InsuredRelationship','CustomerID']]

# %%
PolicyData.head()
# Out:
#    CustomerLoyaltyPeriod InsurancePolicyState InsuredRelationship CustomerID
# 0                    328               State3             husband   Cust1001
# 1                    256               State1           unmarried   Cust1004
# 2                    228               State1           unmarried   Cust1005
# 3                    256               State3           unmarried   Cust1006
# 4                    137               State2             husband   Cust1007

# %%
cur, conn = create_database()

# %%
claim_table_create = ("""CREATE TABLE IF NOT EXISTS claimdata(
CustomerID VARCHAR PRIMARY KEY,
TypeOfIncident VARCHAR,
TypeOfCollission VARCHAR,
IncidentState VARCHAR,
AmountOfTotalClaim VARCHAR
)""")

# %%
cur.execute(claim_table_create)
conn.commit()

# %%
demographics_table_create = ("""CREATE TABLE IF NOT EXISTS demographicsdata(
CustomerID VARCHAR,
InsuredAge VARCHAR,
InsuredGender VARCHAR,
InsuredEducationLevel VARCHAR,
InsuredOccupation VARCHAR,
InsuredHobbies VARCHAR
)""")

cur.execute(demographics_table_create)
conn.commit()

# %%
policy_table_create = ("""CREATE TABLE IF NOT EXISTS policydata(
CustomerLoyaltyPeriod INT ,
InsurancePolicyState VARCHAR,
InsuredRelationship VARCHAR,
CustomerID VARCHAR
)""")

# %%
claim_table_insert = ("""INSERT INTO claimdata(
CustomerID,
TypeOfIncident,
TypeOfCollission,
IncidentState,
AmountOfTotalClaim)
VALUES (%s,%s,%s,%s,%s)
""")

# %%
for i, row in ClaimData_clean.iterrows():
    cur.execute(claim_table_insert, list(row))
    #     print(list(row))

# %%
conn.commit()

# %%
demographics_table_insert = ("""INSERT INTO demographicsdata(
CustomerID ,
InsuredAge ,
InsuredGender,
InsuredEducationLevel ,
InsuredOccupation ,
InsuredHobbies)
VALUES (%s,%s,%s,%s,%s,%s)
""")

# %%
for i, row in DemographicsData.iterrows():
    cur.execute(demographics_table_insert, list(row))

# %%
conn.commit()

# %%
policy_table_insert = ("""INSERT INTO policydata(
CustomerLoyaltyPeriod ,
InsurancePolicyState ,
InsuredRelationship ,
CustomerID)
VALUES (%s,%s,%s,%s)
""")

# %%
for i, row in PolicyData.iterrows():
    cur.execute(policy_table_insert, list(row))

# %%
conn.commit()
